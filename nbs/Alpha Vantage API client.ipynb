# %%
import requests
from dataclasses import dataclass
from typing import Literal
from datetime import datetime
from decimal import Decimal

import pytz
from decouple import config
from urllib.parse import urlencode

# %%
ALPHAVANTAGE_API_KEY = config('ALPHAVANTAGE_API_KEY', default=None, cast=str)

def transform_alpha_vantage_result(timestamp_str, result):
    timestamp_format = '%Y-%m-%d %H:%M:%S'
    eastern_timezone = pytz.timezone('US/Eastern')
    utc_timezone = pytz.utc

    timestamp = eastern_timezone.localize(datetime.strptime(timestamp_str, timestamp_format)).astimezone(utc_timezone)
    return {
        'open_price': Decimal(result['1. open']),
        'close_price': Decimal(result['4. close']),
        'high_price': Decimal(result['2. high']),
        'low_price': Decimal(result['3. low']),        
        "number_of_transactions": None,
        'volume': int(result['5. volume']),
        "volume_weighted_average": None,
        "time": timestamp
    }


@dataclass
class AlphaVantageAPIClient:
    ticker: str = 'AAPL'
    function: Literal["TIME_SERIES_INTRADAY", "TIME_SERIES_DAILY", "TIME_SERIES_WEEKLY", "TIME_SERIES_MONTHLY"] = "TIME_SERIES_INTRADAY"
    interval: Literal["1min", "5min", "15min", "30min", "60min"] = "1min"
    adjusted: bool = True
    
    multiplier: int = 5
    timespan: str = "day"
    from_date: str = "2023-01-09"
    to_date: str = "2023-01-10"
    api_key: str = ""
    adjusted: bool = True
    

    def get_api_key(self):
        return self.api_key or ALPHAVANTAGE_API_KEY
        
    def get_headers(self):
        api_key = self.get_api_key()
        return {
            "Authorization": f"Bearer {api_key}"
        }
    
    def get_params(self):
        return {
            "apikey": self.get_api_key(),
            "symbol": self.ticker,
            "interval": self.interval,
            "function": self.function,
            # "adjusted": self.adjusted,
        }
    
    def generate_url(self, pass_auth: bool = False):
        url = f"https://www.alphavantage.co/query"
        params = self.get_params()
        encoded_params = urlencode(params)        
        url = f"{url}?{encoded_params}"
        if pass_auth:
            url = f"{url}&api_Key={self.get_api_key()}"
        return url

    def fetch_data(self):
        url = self.generate_url()
        headers = self.get_headers()
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        return response.json()

    def get_stock_data(self):
        data = self.fetch_data()
        dataset_keys = [x for x in data.keys() if not x.startswith('Meta Data')]
        # print(dataset_keys)
        results = data[dataset_keys[0]]
        return [transform_alpha_vantage_result(timestamp_str, result) for timestamp_str, result in results.items() if timestamp_str != 'Meta Data']

# %%
AlphaVantageAPIClient().get_stock_data()
# Out:
# [{'open_price': Decimal('258.1300'),
#   'close_price': Decimal('258.1600'),
#   'high_price': Decimal('258.1600'),
#   'low_price': Decimal('258.1000'),
#   'number_of_transactions': None,
#   'volume': 335,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 59, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.1100'),
#   'close_price': Decimal('258.1101'),
#   'high_price': Decimal('258.1600'),
#   'low_price': Decimal('258.0900'),
#   'number_of_transactions': None,
#   'volume': 648,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 58, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.1200'),
#   'close_price': Decimal('258.1300'),
#   'high_price': Decimal('258.1600'),
#   'low_price': Decimal('258.1050'),
#   'number_of_transactions': None,
#   'volume': 123,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 57, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.1400'),
#   'close_price': Decimal('258.1050'),
#   'high_price': Decimal('258.1400'),
#   'low_price': Decimal('258.0700'),
#   'number_of_transactions': None,
#   'volume': 120,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 56, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.1100'),
#   'close_price': Decimal('258.1300'),
#   'high_price': Decimal('258.1300'),
#   'low_price': Decimal('258.0700'),
#   'number_of_transactions': None,
#   'volume': 115,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.1388'),
#   'close_price': Decimal('258.1300'),
#   'high_price': Decimal('258.1400'),
#   'low_price': Decimal('258.1050'),
#   'number_of_transactions': None,
#   'volume': 104,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 54, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.1100'),
#   'close_price': Decimal('258.1050'),
#   'high_price': Decimal('258.1398'),
#   'low_price': Decimal('258.1000'),
#   'number_of_transactions': None,
#   'volume': 18,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 53, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.1000'),
#   'close_price': Decimal('258.1000'),
#   'high_price': Decimal('258.1482'),
#   'low_price': Decimal('258.0600'),
#   'number_of_transactions': None,
#   'volume': 2445,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 52, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.1000'),
#   'close_price': Decimal('258.1000'),
#   'high_price': Decimal('258.1300'),
#   'low_price': Decimal('258.0100'),
#   'number_of_transactions': None,
#   'volume': 1186,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 51, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.1200'),
#   'close_price': Decimal('257.9842'),
#   'high_price': Decimal('258.1700'),
#   'low_price': Decimal('257.9750'),
#   'number_of_transactions': None,
#   'volume': 2049,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.1400'),
#   'close_price': Decimal('258.0450'),
#   'high_price': Decimal('258.1400'),
#   'low_price': Decimal('258.0450'),
#   'number_of_transactions': None,
#   'volume': 31,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 49, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.0550'),
#   'close_price': Decimal('258.1400'),
#   'high_price': Decimal('258.1400'),
#   'low_price': Decimal('257.9500'),
#   'number_of_transactions': None,
#   'volume': 36,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 48, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.1100'),
#   'close_price': Decimal('258.1500'),
#   'high_price': Decimal('258.1500'),
#   'low_price': Decimal('257.9700'),
#   'number_of_transactions': None,
#   'volume': 128,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 47, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.1100'),
#   'close_price': Decimal('258.0550'),
#   'high_price': Decimal('258.1500'),
#   'low_price': Decimal('257.9500'),
#   'number_of_transactions': None,
#   'volume': 715,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 46, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.1100'),
#   'close_price': Decimal('258.1000'),
#   'high_price': Decimal('258.1600'),
#   'low_price': Decimal('258.0600'),
#   'number_of_transactions': None,
#   'volume': 107,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.1800'),
#   'close_price': Decimal('258.1000'),
#   'high_price': Decimal('258.1800'),
#   'low_price': Decimal('258.0500'),
#   'number_of_transactions': None,
#   'volume': 88,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 44, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.0700'),
#   'close_price': Decimal('258.1150'),
#   'high_price': Decimal('258.1700'),
#   'low_price': Decimal('258.0000'),
#   'number_of_transactions': None,
#   'volume': 70,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 43, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.0600'),
#   'close_price': Decimal('258.1800'),
#   'high_price': Decimal('258.1800'),
#   'low_price': Decimal('258.0000'),
#   'number_of_transactions': None,
#   'volume': 2193,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 42, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9900'),
#   'close_price': Decimal('258.0500'),
#   'high_price': Decimal('258.0600'),
#   'low_price': Decimal('257.9600'),
#   'number_of_transactions': None,
#   'volume': 1298,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 41, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9800'),
#   'close_price': Decimal('257.9900'),
#   'high_price': Decimal('257.9900'),
#   'low_price': Decimal('257.9600'),
#   'number_of_transactions': None,
#   'volume': 49,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9600'),
#   'close_price': Decimal('257.9750'),
#   'high_price': Decimal('257.9900'),
#   'low_price': Decimal('257.9600'),
#   'number_of_transactions': None,
#   'volume': 55,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 39, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9600'),
#   'close_price': Decimal('257.9400'),
#   'high_price': Decimal('257.9800'),
#   'low_price': Decimal('257.8900'),
#   'number_of_transactions': None,
#   'volume': 49,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 38, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9500'),
#   'close_price': Decimal('257.9600'),
#   'high_price': Decimal('257.9800'),
#   'low_price': Decimal('257.9500'),
#   'number_of_transactions': None,
#   'volume': 106,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 37, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9700'),
#   'close_price': Decimal('257.9800'),
#   'high_price': Decimal('257.9900'),
#   'low_price': Decimal('257.9500'),
#   'number_of_transactions': None,
#   'volume': 41,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 36, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9500'),
#   'close_price': Decimal('257.9700'),
#   'high_price': Decimal('257.9900'),
#   'low_price': Decimal('257.9500'),
#   'number_of_transactions': None,
#   'volume': 22,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9900'),
#   'close_price': Decimal('257.9800'),
#   'high_price': Decimal('257.9900'),
#   'low_price': Decimal('257.9500'),
#   'number_of_transactions': None,
#   'volume': 11,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 34, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9800'),
#   'close_price': Decimal('257.9600'),
#   'high_price': Decimal('257.9800'),
#   'low_price': Decimal('257.9500'),
#   'number_of_transactions': None,
#   'volume': 151,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 33, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9700'),
#   'close_price': Decimal('257.9800'),
#   'high_price': Decimal('257.9888'),
#   'low_price': Decimal('257.9500'),
#   'number_of_transactions': None,
#   'volume': 16,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 32, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9700'),
#   'close_price': Decimal('257.9800'),
#   'high_price': Decimal('257.9800'),
#   'low_price': Decimal('257.9500'),
#   'number_of_transactions': None,
#   'volume': 177,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 31, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9800'),
#   'close_price': Decimal('257.9500'),
#   'high_price': Decimal('257.9800'),
#   'low_price': Decimal('257.9500'),
#   'number_of_transactions': None,
#   'volume': 52,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9400'),
#   'close_price': Decimal('257.9700'),
#   'high_price': Decimal('257.9900'),
#   'low_price': Decimal('257.8600'),
#   'number_of_transactions': None,
#   'volume': 256,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 29, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9200'),
#   'close_price': Decimal('257.9250'),
#   'high_price': Decimal('257.9900'),
#   'low_price': Decimal('257.8600'),
#   'number_of_transactions': None,
#   'volume': 21,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 28, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8800'),
#   'close_price': Decimal('257.9900'),
#   'high_price': Decimal('257.9900'),
#   'low_price': Decimal('257.8500'),
#   'number_of_transactions': None,
#   'volume': 47,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 27, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9550'),
#   'close_price': Decimal('257.8500'),
#   'high_price': Decimal('257.9550'),
#   'low_price': Decimal('257.8500'),
#   'number_of_transactions': None,
#   'volume': 55,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 26, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9400'),
#   'close_price': Decimal('257.9200'),
#   'high_price': Decimal('257.9900'),
#   'low_price': Decimal('257.8500'),
#   'number_of_transactions': None,
#   'volume': 121,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9400'),
#   'close_price': Decimal('257.9900'),
#   'high_price': Decimal('257.9900'),
#   'low_price': Decimal('257.8500'),
#   'number_of_transactions': None,
#   'volume': 611,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 24, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9450'),
#   'close_price': Decimal('257.9450'),
#   'high_price': Decimal('257.9900'),
#   'low_price': Decimal('257.9400'),
#   'number_of_transactions': None,
#   'volume': 12,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 23, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9450'),
#   'close_price': Decimal('257.9400'),
#   'high_price': Decimal('257.9450'),
#   'low_price': Decimal('257.9000'),
#   'number_of_transactions': None,
#   'volume': 88,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 22, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9300'),
#   'close_price': Decimal('257.9450'),
#   'high_price': Decimal('257.9900'),
#   'low_price': Decimal('257.9000'),
#   'number_of_transactions': None,
#   'volume': 31,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 21, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9450'),
#   'close_price': Decimal('257.9450'),
#   'high_price': Decimal('257.9900'),
#   'low_price': Decimal('257.9000'),
#   'number_of_transactions': None,
#   'volume': 12,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 20, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9350'),
#   'close_price': Decimal('257.9300'),
#   'high_price': Decimal('257.9700'),
#   'low_price': Decimal('257.9000'),
#   'number_of_transactions': None,
#   'volume': 143,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 19, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9350'),
#   'close_price': Decimal('257.9000'),
#   'high_price': Decimal('257.9700'),
#   'low_price': Decimal('257.9000'),
#   'number_of_transactions': None,
#   'volume': 59,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 18, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9000'),
#   'close_price': Decimal('257.9350'),
#   'high_price': Decimal('257.9700'),
#   'low_price': Decimal('257.9000'),
#   'number_of_transactions': None,
#   'volume': 16,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 17, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9050'),
#   'close_price': Decimal('257.9000'),
#   'high_price': Decimal('257.9350'),
#   'low_price': Decimal('257.9000'),
#   'number_of_transactions': None,
#   'volume': 57,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 16, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9000'),
#   'close_price': Decimal('257.9700'),
#   'high_price': Decimal('257.9700'),
#   'low_price': Decimal('257.8400'),
#   'number_of_transactions': None,
#   'volume': 11,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 15, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9100'),
#   'close_price': Decimal('257.9050'),
#   'high_price': Decimal('257.9100'),
#   'low_price': Decimal('257.8400'),
#   'number_of_transactions': None,
#   'volume': 13,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 14, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9050'),
#   'close_price': Decimal('257.9050'),
#   'high_price': Decimal('257.9700'),
#   'low_price': Decimal('257.8900'),
#   'number_of_transactions': None,
#   'volume': 229,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 13, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8850'),
#   'close_price': Decimal('257.8900'),
#   'high_price': Decimal('257.9100'),
#   'low_price': Decimal('257.8400'),
#   'number_of_transactions': None,
#   'volume': 175,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 12, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8650'),
#   'close_price': Decimal('257.8850'),
#   'high_price': Decimal('257.8900'),
#   'low_price': Decimal('257.8650'),
#   'number_of_transactions': None,
#   'volume': 219,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 11, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9000'),
#   'close_price': Decimal('257.8800'),
#   'high_price': Decimal('257.9000'),
#   'low_price': Decimal('257.8400'),
#   'number_of_transactions': None,
#   'volume': 215,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 10, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9000'),
#   'close_price': Decimal('257.8700'),
#   'high_price': Decimal('257.9000'),
#   'low_price': Decimal('257.8400'),
#   'number_of_transactions': None,
#   'volume': 210,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 9, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8600'),
#   'close_price': Decimal('257.8500'),
#   'high_price': Decimal('257.8700'),
#   'low_price': Decimal('257.8500'),
#   'number_of_transactions': None,
#   'volume': 119,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 8, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8450'),
#   'close_price': Decimal('257.8600'),
#   'high_price': Decimal('257.8800'),
#   'low_price': Decimal('257.8410'),
#   'number_of_transactions': None,
#   'volume': 44,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 7, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8200'),
#   'close_price': Decimal('257.8450'),
#   'high_price': Decimal('257.8800'),
#   'low_price': Decimal('257.8100'),
#   'number_of_transactions': None,
#   'volume': 54,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 6, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8600'),
#   'close_price': Decimal('257.8450'),
#   'high_price': Decimal('257.8900'),
#   'low_price': Decimal('257.8100'),
#   'number_of_transactions': None,
#   'volume': 127,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 5, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8600'),
#   'close_price': Decimal('257.8600'),
#   'high_price': Decimal('257.8600'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 129,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 4, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8200'),
#   'close_price': Decimal('257.8600'),
#   'high_price': Decimal('257.9000'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 28,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 3, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8300'),
#   'close_price': Decimal('257.8600'),
#   'high_price': Decimal('257.9000'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 64,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 2, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8200'),
#   'close_price': Decimal('257.8300'),
#   'high_price': Decimal('257.9000'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 273,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 1, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8600'),
#   'close_price': Decimal('257.8600'),
#   'high_price': Decimal('257.9000'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 29,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 21, 0, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8400'),
#   'close_price': Decimal('257.8500'),
#   'high_price': Decimal('257.9000'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 242,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 59, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8300'),
#   'close_price': Decimal('257.9000'),
#   'high_price': Decimal('257.9000'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 1016,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 58, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8500'),
#   'close_price': Decimal('257.8600'),
#   'high_price': Decimal('257.9000'),
#   'low_price': Decimal('257.8300'),
#   'number_of_transactions': None,
#   'volume': 297,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 57, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8200'),
#   'close_price': Decimal('257.8400'),
#   'high_price': Decimal('257.8600'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 27,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 56, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8600'),
#   'close_price': Decimal('257.8400'),
#   'high_price': Decimal('257.8600'),
#   'low_price': Decimal('257.8400'),
#   'number_of_transactions': None,
#   'volume': 7,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8300'),
#   'close_price': Decimal('257.8300'),
#   'high_price': Decimal('257.9000'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 56,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 54, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9000'),
#   'close_price': Decimal('257.8600'),
#   'high_price': Decimal('257.9000'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 1106,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 53, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8200'),
#   'close_price': Decimal('257.8500'),
#   'high_price': Decimal('257.9000'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 1041,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 52, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8200'),
#   'close_price': Decimal('257.8600'),
#   'high_price': Decimal('257.8600'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 20,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 51, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8600'),
#   'close_price': Decimal('257.8600'),
#   'high_price': Decimal('257.9000'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 42,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8750'),
#   'close_price': Decimal('257.8600'),
#   'high_price': Decimal('257.9000'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 6,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 49, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8750'),
#   'close_price': Decimal('257.8800'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 185,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 48, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8800'),
#   'close_price': Decimal('257.8800'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 169,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 47, tzinfo=<UTC>)},
#  {'open_price': Decimal('258.0200'),
#   'close_price': Decimal('258.0600'),
#   'high_price': Decimal('258.0600'),
#   'low_price': Decimal('257.8600'),
#   'number_of_transactions': None,
#   'volume': 9,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 46, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8700'),
#   'close_price': Decimal('257.9800'),
#   'high_price': Decimal('257.9800'),
#   'low_price': Decimal('257.8100'),
#   'number_of_transactions': None,
#   'volume': 15,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9300'),
#   'close_price': Decimal('257.8700'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8100'),
#   'number_of_transactions': None,
#   'volume': 30,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 44, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8100'),
#   'close_price': Decimal('257.8700'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8100'),
#   'number_of_transactions': None,
#   'volume': 45,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 43, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8700'),
#   'close_price': Decimal('257.9300'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8100'),
#   'number_of_transactions': None,
#   'volume': 53,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 42, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8700'),
#   'close_price': Decimal('257.9300'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8000'),
#   'number_of_transactions': None,
#   'volume': 62,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 41, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8650'),
#   'close_price': Decimal('257.8000'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8000'),
#   'number_of_transactions': None,
#   'volume': 92,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8000'),
#   'close_price': Decimal('257.8650'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8000'),
#   'number_of_transactions': None,
#   'volume': 293,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 39, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8800'),
#   'close_price': Decimal('257.8000'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8000'),
#   'number_of_transactions': None,
#   'volume': 197,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 38, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8000'),
#   'close_price': Decimal('257.8650'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8000'),
#   'number_of_transactions': None,
#   'volume': 233,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 37, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8000'),
#   'close_price': Decimal('257.8600'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8000'),
#   'number_of_transactions': None,
#   'volume': 229,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 36, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9000'),
#   'close_price': Decimal('257.8500'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8000'),
#   'number_of_transactions': None,
#   'volume': 530,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8200'),
#   'close_price': Decimal('257.8750'),
#   'high_price': Decimal('257.9000'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 12,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 34, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8700'),
#   'close_price': Decimal('257.9000'),
#   'high_price': Decimal('257.9100'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 273,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 33, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8800'),
#   'close_price': Decimal('257.8300'),
#   'high_price': Decimal('257.8900'),
#   'low_price': Decimal('257.8300'),
#   'number_of_transactions': None,
#   'volume': 153,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 32, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9300'),
#   'close_price': Decimal('257.8800'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8300'),
#   'number_of_transactions': None,
#   'volume': 57,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 31, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8800'),
#   'close_price': Decimal('257.8800'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8400'),
#   'number_of_transactions': None,
#   'volume': 20,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8300'),
#   'close_price': Decimal('257.9000'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8300'),
#   'number_of_transactions': None,
#   'volume': 178,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 29, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9000'),
#   'close_price': Decimal('257.8800'),
#   'high_price': Decimal('257.9700'),
#   'low_price': Decimal('257.8800'),
#   'number_of_transactions': None,
#   'volume': 34,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 28, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9700'),
#   'close_price': Decimal('257.9000'),
#   'high_price': Decimal('257.9700'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 23,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 27, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9300'),
#   'close_price': Decimal('257.9699'),
#   'high_price': Decimal('257.9699'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 332,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 26, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8600'),
#   'close_price': Decimal('257.8200'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 57,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.9300'),
#   'close_price': Decimal('257.8750'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 22,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 24, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8400'),
#   'close_price': Decimal('257.8750'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 42,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 23, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8750'),
#   'close_price': Decimal('257.8200'),
#   'high_price': Decimal('257.9300'),
#   'low_price': Decimal('257.8200'),
#   'number_of_transactions': None,
#   'volume': 75,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 22, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8050'),
#   'close_price': Decimal('257.8200'),
#   'high_price': Decimal('257.8750'),
#   'low_price': Decimal('257.7600'),
#   'number_of_transactions': None,
#   'volume': 2911,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 21, tzinfo=<UTC>)},
#  {'open_price': Decimal('257.8500'),
#   'close_price': Decimal('257.8050'),
#   'high_price': Decimal('257.8500'),
#   'low_price': Decimal('257.7600'),
#   'number_of_transactions': None,
#   'volume': 177,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 12, 24, 20, 20, tzinfo=<UTC>)}]
